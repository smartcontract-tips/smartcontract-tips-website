# %%
import os
import re
from collections import Counter
import json

# %%
tag_pattern = re.compile(r'tags:\s*\[(.*?)\]', re.DOTALL)
tag_counter = Counter()
folder = 'content/'

# %%
for root, _, files in os.walk(folder):
        for file in files:
            if file.endswith(".markdown"):
                filename = os.path.join(root, file)
                print(f"extracting tags from {filename}",'', '\r')
                with open(filename, 'r', encoding='utf-8') as f:
                    fm = f.read()

                
                match = tag_pattern.search(fm)

                if match:
                    tags_str = match.group(1)
                    tags = [tag.strip(' "') for tag in tags_str.split(',')]
                    print(tags)
                    tag_counter.update(tags)
# Out:
# extracting tags from content/_it/posts/2024-08-09-nexera-sfruttato-attacco-da-18m-token-nxra-crolla-40.markdown
# ['nexera', 'exploit', 'tokenization']
# extracting tags from content/_it/posts/2024-09-15-profanity.markdown
# ['profanity', 'vulnerability', 'vanity-address', 'ethereum', 'hack']
# extracting tags from content/_it/posts/2024-10-07-implementazione-e-vantaggi-del-portafoglio-digitale-dellue.markdown
# ['eu-digital-identity-wallet', 'pilot', 'secure', 'certification', 'interoperability', 'eudi', 'identity']
# extracting tags from content/_it/posts/2024-10-22-violazione-della-sicurezza-di-radiant-capital-attacco-sofisticato-da-50.markdown
# ['radiant-capital', 'post-mortem', 'security-breach', 'multi-signature', 'attack-vector', 'hack-explained', 'blind-signing']
# extracting tags from content/_it/posts/2024-02-09-uniswap-v4-hooks-and-new-architecture.markdown
# extracting tags from content/_it/posts/2024-10-26-ecosistema-dellidentit-digitale-in-europa-normativa-e-progetti-pilota.markdown
# ['eu-digital-identity-wallet', 'eidas-regulation', 'digital-identity', 'trust-services', 'cross-border']
# extracting tags from content/_it/posts/2024-01-29-partecipazione-casa-sanremo-invest.markdown
# ['Event']
# extracting tags from content/_it/posts/2024-11-08-polymarket-opportunita-controversie-prevede-vittoria-trump.markdown
# ['trump', 'prediction-market', 'us-elections']
# extracting tags from content/_it/posts/2024-09-04-cambio-di-custodia-di-wbtc-rilancia-interesse-su-alternative-defi.markdown
# ['wbtc', 'defi', 'bitcoin', 'custody', 'decentralized-alternative']
# extracting tags from content/_it/posts/2024-05-12-stages-security-assessment-of-ethereum-rollups.markdown
# ['rollup', 'L2', 'layer-2', 'ethereum', 'scalability', 'zk-rollup', 'optimistic-rollup', 'optimism', 'arbitrum']
# extracting tags from content/_it/posts/2024-06-29-zero-knowledge-proofs-e-problemi-np.markdown
# ['zkp', 'zero-knowledge', 'zero-knowledge-proof', 'np-problem', 'cryptography']
# extracting tags from content/_it/posts/2024-03-26-eidas2-il-quadro-normativo-europeo-identita.markdown
# ['eidas-2.0', 'identity', 'wallet', 'regulation', 'eidas']
# extracting tags from content/_it/posts/2024-09-28-sky-makerdao-riconsidera-wbtc.markdown
# ['sky', 'bitgo', 'wbtc', 'offboarding', 'risk']
# extracting tags from content/_it/posts/2024-08-10-eidas-20-innovazioni-impatti-e-prossime-fasi-di-implementazione.markdown
# ['eidas-2.0', 'revisione-regolamento', 'identità-digitale']
# extracting tags from content/_it/posts/2024-07-19-bond-emesso-dlt-cdp-intesasanpaolo.markdown
# ['bond', 'dlt', 'polygon', 'cdp', 'intesa-sanpaolo', 'banking']
# extracting tags from content/_it/posts/2024-09-17-passkey-la-nuo.markdown
# ['passkey', 'security', 'authentication', 'password', 'technology']
# extracting tags from content/_it/posts/2024-08-29-opensea-si-scontra-con-la-sec-nft-considerati-titoli-finanziari.markdown
# ['opensea', 'sec', 'nft', 'security', 'wells-notice', 'howey-test']
# extracting tags from content/_it/posts/2024-09-08-railgun-blocca-tentativo-di-riciclaggio-di-inferno-drainer-di-174.markdown
# ['crypto', 'scam', 'hack', 'railgun', 'eth']
# extracting tags from content/_it/posts/2024-02-22-confronto-uniswap-staking-ethereum.markdown
# extracting tags from content/_it/posts/2024-09-21-ntt-rivela-innovazione-zkp.markdown
# ['zero-knowledge-proof', 'zkp', 'witness-encryption', 'resettable-statistical-zero-knowledge', 'cryptographic-protocol', 'data-security']
# extracting tags from content/_it/posts/2024-05-18-sandwich-attack-spiegato-bene.markdown
# extracting tags from content/_it/posts/2024-08-31-web3-gli-hack-pi-rilevanti-del-2024.markdown
# ['web3', 'hack', 'security', 'defi', '2024']
# extracting tags from content/_it/posts/2024-11-27-corte-dappello-usa-annulla-sanzioni-contro-tornado-cash.markdown
# ['tornado-cash', 'ofac', 'smart-contract', 'crypto', 'sanctions']
# extracting tags from content/_it/posts/2024-10-01-collaborazione-tra-polygon-labs-e-fabric-per-nuove-verifiable-processing.markdown
# ['verifiable-processing-unit', 'polygon', 'zkp', 'hardware', 'vpu']
# extracting tags from content/_it/posts/2024-09-22-remote-ransomware.markdown
# ['remote-ransomware', 'ransomware', 'endpoint-security', 'encryption', 'network']
# extracting tags from content/_it/posts/2024-01-26-smart-contract-significato-del-termine.markdown
# ['smart-contract']
# extracting tags from content/_it/posts/2024-10-09-lattacco-di-hacker-cinesi-ai-sistemi-di-sorveglianza-mette-a.markdown
# ['encryption', 'backdoor', 'china', 'wiretap', 'security']
# extracting tags from content/_it/posts/2024-02-16-erc404-hybrid-token-standard.markdown
# ['NFT', 'Tokens', 'ERC-404', 'ERC']
# extracting tags from content/_it/posts/2024-08-28-il-furto-milionario-di-dai-cresce-la-minaccia-del-phishing.markdown
# ['hacker', 'phishing', 'dai', 'crypto-whale', 'web3']
# extracting tags from content/_it/posts/2024-08-10-consigli-e-trucchi-per-etici-hacker-di-smart-contract.markdown
# ['smart-contract', 'ethical-hacking-tip', 'blockchain-security']
# extracting tags from content/_it/posts/2024-04-02-buidle-fondo-blackrock-tokenizzazione.markdown
# extracting tags from content/_it/posts/2024-04-19-cinque-passi-per-prepararsi-al-regolamento-dora.markdown
# extracting tags from content/_it/posts/2024-09-08-prepararsi-per-i-cambiamenti-di-granite.markdown
# ['upgrade-proposal', 'granite', 'protocol-upgrade', 'optimism', 'security']
# extracting tags from content/_it/posts/2024-05-31-abstract-accounts-head-first.markdown
# extracting tags from content/_it/posts/2024-08-31-emergenze-e-vulnerabilit-nel-web3-necessit-di-monitoraggio-in-tempo.markdown
# ['audit', 'real-time-monitoring', 'web3', 'smart-contract', 'cyvers.ai']
# extracting tags from content/_it/posts/2025-01-24-eudi-wallet-has-some-design-flaws-expert-says.markdown
# ['eudi', 'security', 'identity', 'europe', 'flaws', 'eidas', 'identity-wallet']
# extracting tags from content/_it/posts/2024-08-06-damn-vulnerable-defi-releases-v4.markdown
# ['damn-vulnerable-defi', 'defi', 'smart-contract', 'blockchain-security', 'crypto-security', 'ethereum', 'solidity', 'foundry', 'cybersecurity', 'bug-bounty', 'web3', 'defi-education', 'smartcontract-security', 'vulnerability', 'tech-news']
# extracting tags from content/_it/posts/2024-08-15-aggiornamento-matic-a-pol-guida-completa-per-settembre.markdown
# ['matic', 'pol', 'migration', 'polygon-4th-september', 'upgrade']
# extracting tags from content/_it/posts/2024-09-29-la-notarizzazione-su-blockchain-garanzia-di-sicurezza-e-valore-legale.markdown
# ['notarizzazione', 'blockchain', 'autenticità', 'documento', 'hash']
# extracting tags from content/_it/posts/2025-01-08-web3-security-2024-in-retrospective copy.markdown
# ['web3', 'security', 'hacks', 'facts', 'figures', '2024', 'retrospective']
# extracting tags from content/_it/posts/2024-06-09-smart-contract-in-bitcoin.markdown
# ['smart contract', 'bitcoin']
# extracting tags from content/_it/posts/2024-04-13-regolamento-dora-e-web3-quali-implicazioni.markdown
# extracting tags from content/_it/posts/2024-08-07-ronin-bridge-hacked.markdown
# ['ronin', 'bridge', 'hack']
# extracting tags from content/_it/posts/2024-09-15-nuova-vulnerabilit-yubikey.markdown
# ['yubikey', 'cloning-attack', 'side-channel', 'cryptographic-flaw', 'infineon']
# extracting tags from content/_it/posts/2024-09-06-proposta-opcat-innovazione-per-la-sicurezza-e-flessibilit-di-bitcoin.markdown
# ['bitcoin', 'op_cat', 'covenant', 'smart-contract', 'blockstream']
# extracting tags from content/_it/posts/2024-03-20-cbdc-le-valute-digitali-a-corso-legale.markdown
# ['CBDC', 'stablecoin']
# extracting tags from content/_it/posts/2024-02-15-uniswap-liquidity-pool-e-impermanent-loss.markdown
# extracting tags from content/_it/posts/2024-11-12-campagna-bluenoroff-hidden-risk-phishing-e-malware-su-macos.markdown
# ['bluenoroff', 'crypto', 'mac', 'persistence', 'malware', 'hack', '🚨']
# extracting tags from content/_it/posts/2024-12-15-infinite-approval-token-pericoli-sicurezza.markdown
# ['erc20', 'erc721', 'smart-contract', 'approval', 'token', 'flash-loan', 'hack']
# extracting tags from content/_it/posts/2024-03-06-cosa-sono-gli-oracoli-negli-smart-contract.markdown
# ['Oracles']
# extracting tags from content/_it/posts/2024-10-30-trader-cinese-accusato-di-riciclare-criptovalute-per-il-lazarus-group.markdown
# ['chinese-trader', 'lazarus-group', 'hacked-crypto', 'yicong-wang', 'crypto']

# %%
tag_counter
# Out:
# Counter({'security': 7,
#          'smart-contract': 7,
#          'hack': 6,
#          'web3': 5,
#          'crypto': 4,
#          'ethereum': 3,
#          'identity': 3,
#          'defi': 3,
#          'bitcoin': 3,
#          'zkp': 3,
#          'vulnerability': 2,
#          'eu-digital-identity-wallet': 2,
#          'eudi': 2,
#          'wbtc': 2,
#          'optimism': 2,
#          'zero-knowledge-proof': 2,
#          'eidas-2.0': 2,
#          'eidas': 2,
#          'polygon': 2,
#          '2024': 2,
#          'encryption': 2,
#          'blockchain-security': 2,
#          'nexera': 1,
#          'exploit': 1,
#          'tokenization': 1,
#          'profanity': 1,
#          'vanity-address': 1,
#          'pilot': 1,
#          'secure': 1,
#          'certification': 1,
#          'interoperability': 1,
#          'radiant-capital': 1,
#          'post-mortem': 1,
#          'security-breach': 1,
#          'multi-signature': 1,
#          'attack-vector': 1,
#          'hack-explained': 1,
#          'blind-signing': 1,
#          'eidas-regulation': 1,
#          'digital-identity': 1,
#          'trust-services': 1,
#          'cross-border': 1,
#          'Event': 1,
#          'trump': 1,
#          'prediction-market': 1,
#          'us-elections': 1,
#          'custody': 1,
#          'decentralized-alternative': 1,
#          'rollup': 1,
#          'L2': 1,
#          'layer-2': 1,
#          'scalability': 1,
#          'zk-rollup': 1,
#          'optimistic-rollup': 1,
#          'arbitrum': 1,
#          'zero-knowledge': 1,
#          'np-problem': 1,
#          'cryptography': 1,
#          'wallet': 1,
#          'regulation': 1,
#          'sky': 1,
#          'bitgo': 1,
#          'offboarding': 1,
#          'risk': 1,
#          'revisione-regolamento': 1,
#          'identità-digitale': 1,
#          'bond': 1,
#          'dlt': 1,
#          'cdp': 1,
#          'intesa-sanpaolo': 1,
#          'banking': 1,
#          'passkey': 1,
#          'authentication': 1,
#          'password': 1,
#          'technology': 1,
#          'opensea': 1,
#          'sec': 1,
#          'nft': 1,
#          'wells-notice': 1,
#          'howey-test': 1,
#          'scam': 1,
#          'railgun': 1,
#          'eth': 1,
#          'witness-encryption': 1,
#          'resettable-statistical-zero-knowledge': 1,
#          'cryptographic-protocol': 1,
#          'data-security': 1,
#          'tornado-cash': 1,
#          'ofac': 1,
#          'sanctions': 1,
#          'verifiable-processing-unit': 1,
#          'hardware': 1,
#          'vpu': 1,
#          'remote-ransomware': 1,
#          'ransomware': 1,
#          'endpoint-security': 1,
#          'network': 1,
#          'backdoor': 1,
#          'china': 1,
#          'wiretap': 1,
#          'NFT': 1,
#          'Tokens': 1,
#          'ERC-404': 1,
#          'ERC': 1,
#          'hacker': 1,
#          'phishing': 1,
#          'dai': 1,
#          'crypto-whale': 1,
#          'ethical-hacking-tip': 1,
#          'upgrade-proposal': 1,
#          'granite': 1,
#          'protocol-upgrade': 1,
#          'audit': 1,
#          'real-time-monitoring': 1,
#          'cyvers.ai': 1,
#          'europe': 1,
#          'flaws': 1,
#          'identity-wallet': 1,
#          'damn-vulnerable-defi': 1,
#          'crypto-security': 1,
#          'solidity': 1,
#          'foundry': 1,
#          'cybersecurity': 1,
#          'bug-bounty': 1,
#          'defi-education': 1,
#          'smartcontract-security': 1,
#          'tech-news': 1,
#          'matic': 1,
#          'pol': 1,
#          'migration': 1,
#          'polygon-4th-september': 1,
#          'upgrade': 1,
#          'notarizzazione': 1,
#          'blockchain': 1,
#          'autenticità': 1,
#          'documento': 1,
#          'hash': 1,
#          'hacks': 1,
#          'facts': 1,
#          'figures': 1,
#          'retrospective': 1,
#          'smart contract': 1,
#          'ronin': 1,
#          'bridge': 1,
#          'yubikey': 1,
#          'cloning-attack': 1,
#          'side-channel': 1,
#          'cryptographic-flaw': 1,
#          'infineon': 1,
#          'op_cat': 1,
#          'covenant': 1,
#          'blockstream': 1,
#          'CBDC': 1,
#          'stablecoin': 1,
#          'bluenoroff': 1,
#          'mac': 1,
#          'persistence': 1,
#          'malware': 1,
#          '🚨': 1,
#          'erc20': 1,
#          'erc721': 1,
#          'approval': 1,
#          'token': 1,
#          'flash-loan': 1,
#          'Oracles': 1,
#          'chinese-trader': 1,
#          'lazarus-group': 1,
#          'hacked-crypto': 1,
#          'yicong-wang': 1})
